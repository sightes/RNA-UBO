# %% [markdown]
# <a href="https://colab.research.google.com/github/sightes/RNA-UBO/blob/main/Anime_GAN's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://raw.githubusercontent.com/sightes/RNA-UBO/main/anime%20lite.zip'
# !unzip "anime lite.zip" -d anime
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: anime/1091.png
#  extracting: anime/1092.png
#  extracting: anime/1093.png
#  extracting: anime/1094.png
#  extracting: anime/1095.png
#  extracting: anime/1096.png
#  extracting: anime/1097.png
#   inflating: anime/1098.png
#  extracting: anime/1099.png
#  extracting: anime/11.png
#  extracting: anime/110.png
#  extracting: anime/1100.png
#  extracting: anime/1101.png
#  extracting: anime/1102.png
#  extracting: anime/1103.png
#  extracting: anime/1104.png
#  extracting: anime/1105.png
#  extracting: anime/1106.png
#  extracting: anime/1107.png
#  extracting: anime/1108.png
#  extracting: anime/1109.png
#  extracting: anime/111.png
#  extracting: anime/1110.png
#  extracting: anime/1111.png
#  extracting: anime/1112.png
#  extracting: anime/1113.png
#  extracting: anime/1114.png
#  extracting: anime/1115.png
#  extracting: anime/1116.png
#  extracting: anime/1117.png
#  extracting: anime/1118.png
#  extracting: anime/1119.png
#  extracting: anime/112.png
#  extracting: anime/1120.png
#  extracting: anime/1121.png
#   inflating: anime/1122.png
#  extracting: anime/1123.png
#  extracting: anime/1124.png
#  extracting: anime/1125.png
#  extracting: anime/1126.png
#  extracting: anime/1127.png
#  extracting: anime/1128.png
#  extracting: anime/1129.png
#  extracting: anime/113.png
#  extracting: anime/1130.png
#  extracting: anime/1131.png
#  extracting: anime/1132.png
#  extracting: anime/1133.png
#  extracting: anime/1134.png
#  extracting: anime/1135.png
#  extracting: anime/1136.png
#  extracting: anime/1137.png
#  extracting: anime/1138.png
#  extracting: anime/1139.png
#  extracting: anime/114.png
#  extracting: anime/1140.png
#  extracting: anime/1141.png
#  extracting: anime/1142.png
#  extracting: anime/1143.png
#   inflating: anime/1144.png
#  extracting: anime/1145.png
#  extracting: anime/1146.png
#  extracting: anime/1147.png
#  extracting: anime/1148.png
#  extracting: anime/1149.png
#  extracting: anime/115.png
#  extracting: anime/1150.png
#  extracting: anime/1151.png
#  extracting: anime/1152.png
#  extracting: anime/1153.png
#  extracting: anime/1154.png
#  extracting: anime/1155.png
#  extracting: anime/1156.png
#  extracting: anime/1157.png
#  extracting: anime/1158.png
#  extracting: anime/1159.png
#  extracting: anime/116.png
#  extracting: anime/1160.png
#  extracting: anime/1161.png
#  extracting: anime/1162.png
#  extracting: anime/1163.png
#  extracting: anime/1164.png
#   inflating: anime/1165.png
#  extracting: anime/1166.png
#  extracting: anime/1167.png
#  extracting: anime/1168.png
#  extracting: anime/1169.png
#  extracting: anime/117.png
#  extracting: anime/1170.png
#   inflating: anime/1171.png
#  extracting: anime/1172.png
#  extracting: anime/1173.png
#  extracting: anime/1174.png
#  extracting: anime/1175.png
#   inflating: anime/1176.png
#  extracting: anime/1177.png
#   inflating: anime/1178.png
#   inflating: anime/1179.png
#  extracting: anime/118.png
#  extracting: anime/1180.png
#  extracting: anime/1181.png
#  extracting: anime/1182.png
#  extracting: anime/1183.png
#  extracting: anime/1184.png
#  extracting: anime/911.png
#  extracting: anime/912.png
#  extracting: anime/913.png
#  extracting: anime/914.png
#  extracting: anime/915.png
#  extracting: anime/916.png
#  extracting: anime/917.png
#  extracting: anime/918.png
#  extracting: anime/919.png
#  extracting: anime/92.png
#  extracting: anime/920.png
#  extracting: anime/921.png
#  extracting: anime/922.png
#  extracting: anime/923.png
#  extracting: anime/924.png
#  extracting: anime/925.png
#  extracting: anime/926.png
#  extracting: anime/927.png
#  extracting: anime/928.png
#  extracting: anime/929.png
#  extracting: anime/93.png
#  extracting: anime/930.png
#  extracting: anime/931.png
#  extracting: anime/932.png
#  extracting: anime/933.png
#  extracting: anime/934.png
#  extracting: anime/935.png
#  extracting: anime/936.png
#  extracting: anime/937.png
#  extracting: anime/938.png
#  extracting: anime/939.png
#  extracting: anime/94.png
#  extracting: anime/940.png
#  extracting: anime/941.png
#  extracting: anime/942.png
#  extracting: anime/943.png
#  extracting: anime/944.png
#  extracting: anime/945.png
#  extracting: anime/946.png
#  extracting: anime/947.png
#  extracting: anime/948.png
#  extracting: anime/949.png
#  extracting: anime/95.png
#  extracting: anime/950.png
#  extracting: anime/951.png
#   inflating: anime/952.png
#  extracting: anime/953.png
#  extracting: anime/954.png
#  extracting: anime/955.png
#  extracting: anime/956.png
#  extracting: anime/957.png
#  extracting: anime/958.png
#  extracting: anime/959.png
#  extracting: anime/96.png
#  extracting: anime/960.png
#  extracting: anime/961.png
#  extracting: anime/962.png
#  extracting: anime/963.png
#  extracting: anime/964.png
#  extracting: anime/965.png
#  extracting: anime/966.png
#  extracting: anime/967.png
#  extracting: anime/968.png
#   inflating: anime/969.png
#  extracting: anime/97.png
#  extracting: anime/970.png
#  extracting: anime/971.png
#  extracting: anime/972.png
#  extracting: anime/973.png
#  extracting: anime/974.png
#  extracting: anime/975.png
#  extracting: anime/976.png
#  extracting: anime/977.png
#  extracting: anime/978.png
#  extracting: anime/979.png
#  extracting: anime/98.png
#  extracting: anime/980.png
#  extracting: anime/981.png
#  extracting: anime/982.png
#  extracting: anime/983.png
#  extracting: anime/984.png
#  extracting: anime/985.png
#  extracting: anime/986.png
#  extracting: anime/987.png
#  extracting: anime/988.png
#  extracting: anime/989.png
#  extracting: anime/99.png
#   inflating: anime/990.png
#  extracting: anime/991.png
#  extracting: anime/992.png
#  extracting: anime/993.png
#  extracting: anime/994.png
#  extracting: anime/995.png
#  extracting: anime/996.png
#  extracting: anime/997.png
#  extracting: anime/998.png
#  extracting: anime/999.png

# %%
# !mkdir animeGenerated

# %%
import numpy as np
import os 
import matplotlib.pyplot as plt
import cv2

import warnings
warnings.filterwarnings('ignore')

import keras
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential, Model
from keras.layers import Dense, LeakyReLU, Reshape, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Conv2DTranspose

from tensorflow.compat.v1.keras.layers import BatchNormalization

# %%
def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath
                
def load_images(directory='', size=(64,64)):
    images = []
    labels = []  # Integers corresponding to the categories in alphabetical order
    label = 0
    
    imagePaths = list(list_images(directory))
    
    for path in imagePaths:
        
        if not('OSX' in path):
        
            path = path.replace('\\','/')

            image = cv2.imread(path) #Reading the image with OpenCV
            image = cv2.resize(image,size) #Resizing the image, in case some are not of the same size

            images.append(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    return images

# %%
images=load_images('./anime')

# %%
_,ax = plt.subplots(5,5, figsize = (8,8)) 
for i in range(5):
    for j in range(5):
        ax[i,j].imshow(images[5*i+j])
        ax[i,j].axis('off')

# %%
class GAN():
    def __init__(self):
        self.img_shape = (64, 64, 3)
        
        self.noise_size = 100

        optimizer = Adam(0.0002,0.5)

        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy', 
                                   optimizer=optimizer,
                                   metrics=['accuracy'])

        self.generator = self.build_generator()
        self.generator.compile(loss='binary_crossentropy', optimizer=optimizer)
        
        self.combined = Sequential()
        self.combined.add(self.generator)
        self.combined.add(self.discriminator)
        
        self.discriminator.trainable = False
        
        self.combined.compile(loss='binary_crossentropy', optimizer=optimizer)
        
        self.combined.summary()
        
    # Creating the generator, the large kernels in the convolutional layers allow the network to create complex structures.
    def build_generator(self):
        epsilon = 0.00001 # Small float added to variance to avoid dividing by zero in the BatchNorm layers.
        noise_shape = (self.noise_size,)
        
        model = Sequential()
        
        model.add(Dense(4*4*512, activation='linear', input_shape=noise_shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Reshape((4, 4, 512)))
        
        model.add(Conv2DTranspose(512, kernel_size=[4,4], strides=[2,2], padding="same",
                                  kernel_initializer= keras.initializers.TruncatedNormal(stddev=0.02)))
        model.add(BatchNormalization(momentum=0.9, epsilon=epsilon))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2DTranspose(256, kernel_size=[4,4], strides=[2,2], padding="same",
                                  kernel_initializer= keras.initializers.TruncatedNormal(stddev=0.02)))
        model.add(BatchNormalization(momentum=0.9, epsilon=epsilon))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2DTranspose(128, kernel_size=[4,4], strides=[2,2], padding="same",
                                  kernel_initializer= keras.initializers.TruncatedNormal(stddev=0.02)))
        model.add(BatchNormalization(momentum=0.9, epsilon=epsilon))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2DTranspose(64, kernel_size=[4,4], strides=[2,2], padding="same",
                                  kernel_initializer= keras.initializers.TruncatedNormal(stddev=0.02)))
        model.add(BatchNormalization(momentum=0.9, epsilon=epsilon))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2DTranspose(3, kernel_size=[4,4], strides=[1,1], padding="same",
                                  kernel_initializer= keras.initializers.TruncatedNormal(stddev=0.02)))

        # Standard activation for the generator of a GAN
        model.add(Activation("tanh"))
        
        model.summary()

        noise = Input(shape=noise_shape)
        img = model(noise)

        return Model(noise, img)

    def build_discriminator(self):

        model = Sequential()

        model.add(Conv2D(128, (3,3), padding='same', input_shape=self.img_shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization())
        model.add(Conv2D(128, (3,3), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(3,3)))
        model.add(Dropout(0.2))

        model.add(Conv2D(128, (3,3), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization())
        model.add(Conv2D(128, (3,3), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(3,3)))
        model.add(Dropout(0.3))

        model.add(Flatten())
        model.add(Dense(128))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(128))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))
        
        model.summary()
        
        img = Input(shape=self.img_shape)
        validity = model(img)

        return Model(img, validity)

    def train(self, epochs, batch_size=128, metrics_update=50, save_images=100, save_model=2000):

        X_train = np.array(images)
        X_train = (X_train.astype(np.float32) - 127.5) / 127.5

        half_batch = int(batch_size / 2)
        
        mean_d_loss=[0,0]
        mean_g_loss=0

        for epoch in range(epochs):
            idx = np.random.randint(0, X_train.shape[0], half_batch)
            imgs = X_train[idx]

            noise = np.random.normal(0, 1, (half_batch, self.noise_size))
            gen_imgs = self.generator.predict(noise)

            # Training the discriminator
            
            # The loss of the discriminator is the mean of the losses while training on authentic and fake images
            d_loss = 0.5 * np.add(self.discriminator.train_on_batch(imgs, np.ones((half_batch, 1))),
                                  self.discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1))))

            # Training the generator
            for _ in range(2):
                noise = np.random.normal(0, 1, (batch_size, self.noise_size))

                valid_y = np.array([1] * batch_size)
                g_loss = self.combined.train_on_batch(noise, valid_y)
            
            mean_d_loss[0] += d_loss[0]
            mean_d_loss[1] += d_loss[1]
            mean_g_loss += g_loss
            
            # We print the losses and accuracy of the networks every 200 batches mainly to make sure the accuracy of the discriminator
            # is not stable at around 50% or 100% (which would mean the discriminator performs not well enough or too well)
            if epoch % metrics_update == 0:
                print ("%d [Discriminator loss: %f, acc.: %.2f%%] [Generator loss: %f]" % (epoch, mean_d_loss[0]/metrics_update, 100*mean_d_loss[1]/metrics_update, mean_g_loss/metrics_update))
                mean_d_loss=[0,0]
                mean_g_loss=0
            
            # Saving 25 images
            if epoch % save_images == 0:
                self.save_images(epoch)
            
            # We save the architecture of the model, the weights and the state of the optimizer
            # This way we can restart the training exactly where we stopped
            if epoch % save_model == 0:
                self.generator.save("generator_%d" % epoch)
                self.discriminator.save("discriminator_%d" % epoch)

    # Saving 25 generated images to have a representation of the spectrum of images created by the generator
    def save_images(self, epoch):
        noise = np.random.normal(0, 1, (25, self.noise_size))
        gen_imgs = self.generator.predict(noise)
        
        # Rescale from [-1,1] into [0,1]
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(5,5, figsize = (8,8))

        for i in range(5):
            for j in range(5):
                axs[i,j].imshow(gen_imgs[5*i+j])
                axs[i,j].axis('off')

        plt.show()
        
        fig.savefig("animeGenerated/Faces_%d.png" % epoch)
        plt.close()

# %%
gan=GAN()
gan.train(epochs=5001, batch_size=500, metrics_update=200, save_images=1000, save_model=15000)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 128)       3584
#
#  leaky_re_lu (LeakyReLU)     (None, 64, 64, 128)       0
#
#  batch_normalization (BatchN  (None, 64, 64, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 128)       147584
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 21, 21, 128)      0
#  )
#
#  dropout (Dropout)           (None, 21, 21, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       147584
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 21, 21, 128)       0
#
#  batch_normalization_2 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       147584
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 21, 21, 128)       0
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,267,969
# Trainable params: 1,266,945
# Non-trainable params: 1,024
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 8192)              827392
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 8192)              0
#
#  reshape (Reshape)           (None, 4, 4, 512)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 512)        4194816
#  nspose)
#
#  batch_normalization_4 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 512)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 256)      2097408
#  ranspose)
#
#  batch_normalization_5 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 128)      524416
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 64, 64, 64)       131136
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 64, 64, 3)        3075
#  ranspose)
#
#  activation (Activation)     (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 7,782,083
# Trainable params: 7,780,163
# Non-trainable params: 1,920
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, 64, 64, 3)         7782083
#
#  model (Functional)          (None, 1)                 1267969
#
# =================================================================
# Total params: 9,050,052
# Trainable params: 7,780,163
# Non-trainable params: 1,269,889
# _________________________________________________________________
# 0 [Discriminator loss: 0.042222, acc.: 0.25%] [Generator loss: 0.000094]
# INFO:tensorflow:Assets written to: generator_0/assets
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f0db7c6d0> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f0db13050> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f0daf0310> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f0dba7c90> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# INFO:tensorflow:Assets written to: discriminator_0/assets
# INFO:tensorflow:Assets written to: discriminator_0/assets
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f220c4b10> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f220633d0> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f22076090> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.normalization.batch_normalization_v1.BatchNormalization object at 0x7f6f0dbcdad0> has the same name 'BatchNormalization' as a built-in Keras object. Consider renaming <class 'keras.layers.normalization.batch_normalization_v1.BatchNormalization'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
